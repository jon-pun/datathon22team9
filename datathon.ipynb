# %%
import pandas as pd

ny311 = pd.read_csv("New_York_NY_311.csv")
ny311.head()
# Out:
# /Users/jonathanyun/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (8,18,29,30) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    Unique Key            Created Date             Closed Date Agency  \
# 0    45282225  01/01/2020 12:01:12 AM  01/01/2020 03:07:10 AM   NYPD
# 1    45281175  01/01/2020 12:01:37 AM  01/01/2020 01:54:21 AM   NYPD
# 2    45278238  01/01/2020 12:01:46 AM  01/01/2020 05:37:46 AM   NYPD
# 3    45280733  01/01/2020 12:01:56 AM  01/01/2020 07:48:16 AM   NYPD
# 4    45281554  01/01/2020 12:03:23 AM  01/01/2020 05:24:53 AM   NYPD
#
#                        Agency Name       Complaint Type        Descriptor  \
# 0  New York City Police Department     Blocked Driveway         No Access
# 1  New York City Police Department  Noise - Residential  Loud Music/Party
# ...
